# %% [markdown]
# # CODE

# %%
# Algoritma genetika untuk menemukan nilai a, b, c, dan d yang memenuhi fungsi f(x) = ((a+2b+3c-4d)-30)
import random

# Mendeclare fungsi
def fitness(individual):
    a, b, c, d = individual
    result = (a + 2*b + 3*c + 4*d) - 30
    return abs(result)  # Mendeclare syarat bahwa nilai fitness yang sebisa mungkin mendekati atau menyentuh angka 0

# 1. Inisialisasi (berdasarkan PPT)
def initialize_population(pop_size, gene_length):
    # Inisialisasi populasi dengan nilai berkisar diantara 0-30 untuk setiap gen
    population = []
    for _ in range(pop_size):
        individual = [random.randint(0, 30) for _ in range(gene_length)]  # range nilai a, b, c, dan d berkisar diantara 0-30
        population.append(individual)
    return population

# 2. Evaluasi
def evaluate_population(population):
    fitness_scores = []
    for individual in population:
        score = fitness(individual)
        fitness_scores.append(score)
    return fitness_scores

# 3. Seleksi (Menggunakan metode Roulette Wheel)
def selection(population, fitness_scores):
    total_fitness = sum(fitness_scores)
    # Menambahkan 1 untuk menghindari masalah berupa operasi pembagian dengan 0
    selection_probs = [1 - (score / (total_fitness + 1)) for score in fitness_scores]
    selected = random.choices(population, weights=selection_probs, k=2)
    return selected

# 4. Rekombinasi (Menggunakan metode Single-Point Crossover)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

# 5. Mutasi (Dengan menggunakan metode acak)
def mutate(individual, mutation_rate=0.01):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = random.randint(0, 30)  # Bermutasi dengan menciptakan nilai acak yang baru untuk gen tsb
    return individual

# Fungsi Utama untuk menjalankan algoritma genetika
def genetic_algorithm(pop_size=10, gene_length=4, generations=100, mutation_rate=0.01): # Mendeclare Tuning Parameters
    # Menampilkan tuning parameters
    print(f"Running GA with population size: {pop_size}, generations: {generations}, mutation rate: {mutation_rate}")
    
    population = initialize_population(pop_size, gene_length)
    
    for generation in range(generations):
        fitness_scores = evaluate_population(population)
        
        # Mencari solusi terbaik
        best_fitness = min(fitness_scores)
        best_individual = population[fitness_scores.index(best_fitness)]
        
        print(f"Generation {generation}, Best fitness: {best_fitness}, Best individual: {best_individual}")
        
        # Melakukan Crosscheck solusi
        if best_fitness == 0:
            print(f"Exact solution found at generation {generation}: {best_individual}")
            return best_individual
        
        # Seleksi, Rekombinasi, dan Mutasi
        new_population = []
        while len(new_population) < pop_size:
            parent1, parent2 = selection(population, fitness_scores)
            child1, child2 = crossover(parent1, parent2)
            child1 = mutate(child1, mutation_rate)
            child2 = mutate(child2, mutation_rate)
            new_population.append(child1)
            new_population.append(child2)
        
        population = new_population[:pop_size]  # MEmastikan ukuran populasi tetap dalam track yang benar atau konstan
    
    # Mengembalikan nilai individu terbaik jika solusi yang tepat belum ditemukan
    print(f"No exact solution found.\nBest solution after {generations} generations: {best_individual} \nWith Best fitness: {best_fitness}")
    return best_individual

# Menjalankan algoritma genetika
genetic_algorithm(pop_size=6, generations=200, mutation_rate=0.05)
# Out:
# Running GA with population size: 6, generations: 200, mutation rate: 0.05
# Generation 0, Best fitness: 30, Best individual: [13, 14, 5, 1]
# Generation 1, Best fitness: 42, Best individual: [25, 14, 5, 1]
# Generation 2, Best fitness: 58, Best individual: [2, 9, 16, 5]
# Generation 3, Best fitness: 55, Best individual: [13, 4, 16, 4]
# Generation 4, Best fitness: 59, Best individual: [13, 4, 16, 5]
# Generation 5, Best fitness: 54, Best individual: [2, 9, 16, 4]
# Generation 6, Best fitness: 59, Best individual: [13, 4, 16, 5]
# Generation 7, Best fitness: 63, Best individual: [7, 9, 16, 5]
# Generation 8, Best fitness: 68, Best individual: [22, 4, 16, 5]
# Generation 9, Best fitness: 47, Best individual: [22, 4, 9, 5]
# Generation 10, Best fitness: 68, Best individual: [22, 4, 16, 5]
# Generation 11, Best fitness: 68, Best individual: [22, 4, 16, 5]
# Generation 12, Best fitness: 68, Best individual: [22, 4, 16, 5]
# Generation 13, Best fitness: 68, Best individual: [22, 4, 16, 5]
# Generation 14, Best fitness: 100, Best individual: [22, 20, 16, 5]
# Generation 15, Best fitness: 66, Best individual: [22, 3, 16, 5]
# Generation 16, Best fitness: 100, Best individual: [22, 20, 16, 5]
# Generation 17, Best fitness: 70, Best individual: [22, 5, 16, 5]
# Generation 18, Best fitness: 73, Best individual: [22, 20, 7, 5]
# Generation 19, Best fitness: 73, Best individual: [22, 20, 7, 5]
# Generation 20, Best fitness: 73, Best individual: [22, 20, 7, 5]
# Generation 21, Best fitness: 91, Best individual: [22, 20, 13, 5]
# Generation 22, Best fitness: 91, Best individual: [22, 20, 13, 5]
# Generation 23, Best fitness: 60, Best individual: [22, 4, 16, 3]
# Generation 24, Best fitness: 59, Best individual: [22, 4, 13, 5]
# Generation 25, Best fitness: 59, Best individual: [22, 4, 13, 5]
# Generation 26, Best fitness: 59, Best individual: [22, 4, 13, 5]
# Generation 27, Best fitness: 59, Best individual: [22, 4, 13, 5]
# Generation 28, Best fitness: 52, Best individual: [6, 4, 16, 5]
# Generation 29, Best fitness: 52, Best individual: [6, 4, 16, 5]
# Generation 30, Best fitness: 52, Best individual: [6, 4, 16, 5]
# Generation 31, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 32, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 33, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 34, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 35, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 36, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 37, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 38, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 39, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 40, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 41, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 42, Best fitness: 14, Best individual: [6, 0, 6, 5]
# Generation 43, Best fitness: 13, Best individual: [5, 0, 6, 5]
# Generation 44, Best fitness: 38, Best individual: [6, 0, 6, 11]
# Generation 45, Best fitness: 46, Best individual: [6, 0, 6, 13]
# Generation 46, Best fitness: 50, Best individual: [6, 0, 18, 5]
# Generation 47, Best fitness: 15, Best individual: [5, 1, 6, 5]
# Generation 48, Best fitness: 28, Best individual: [18, 1, 6, 5]
# Generation 49, Best fitness: 28, Best individual: [18, 1, 6, 5]
# Generation 50, Best fitness: 28, Best individual: [18, 1, 6, 5]
# Generation 51, Best fitness: 14, Best individual: [4, 1, 6, 5]
# Generation 52, Best fitness: 14, Best individual: [4, 1, 6, 5]
# Generation 53, Best fitness: 14, Best individual: [4, 1, 6, 5]
# Generation 54, Best fitness: 40, Best individual: [4, 14, 6, 5]
# Generation 55, Best fitness: 40, Best individual: [4, 14, 6, 5]
# Generation 56, Best fitness: 46, Best individual: [4, 21, 6, 3]
# Generation 57, Best fitness: 30, Best individual: [4, 9, 6, 5]
# Generation 58, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 59, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 60, Best fitness: 31, Best individual: [1, 11, 6, 5]
# Generation 61, Best fitness: 22, Best individual: [1, 11, 3, 5]
# Generation 62, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 63, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 64, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 65, Best fitness: 29, Best individual: [1, 10, 6, 5]
# Generation 66, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 67, Best fitness: 50, Best individual: [1, 10, 13, 5]
# Generation 68, Best fitness: 45, Best individual: [4, 21, 3, 5]
# Generation 69, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 70, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 71, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 72, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 73, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 74, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 75, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 76, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 77, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 78, Best fitness: 54, Best individual: [4, 21, 6, 5]
# Generation 79, Best fitness: 92, Best individual: [4, 22, 18, 5]
# Generation 80, Best fitness: 92, Best individual: [4, 22, 18, 5]
# Generation 81, Best fitness: 72, Best individual: [4, 22, 18, 0]
# Generation 82, Best fitness: 72, Best individual: [4, 22, 18, 0]
# Generation 83, Best fitness: 72, Best individual: [4, 22, 18, 0]
# Generation 84, Best fitness: 42, Best individual: [4, 7, 18, 0]
# Generation 85, Best fitness: 42, Best individual: [4, 7, 18, 0]
# Generation 86, Best fitness: 38, Best individual: [4, 5, 18, 0]
# Generation 87, Best fitness: 30, Best individual: [4, 1, 18, 0]
# Generation 88, Best fitness: 30, Best individual: [4, 1, 18, 0]
# Generation 89, Best fitness: 30, Best individual: [4, 1, 18, 0]
# Generation 90, Best fitness: 30, Best individual: [4, 1, 18, 0]
# Generation 91, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 92, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 93, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 94, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 95, Best fitness: 20, Best individual: [18, 1, 10, 0]
# Generation 96, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 97, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 98, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 99, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 100, Best fitness: 44, Best individual: [18, 1, 18, 0]
# Generation 101, Best fitness: 42, Best individual: [16, 1, 18, 0]
# Generation 102, Best fitness: 31, Best individual: [5, 1, 18, 0]
# Generation 103, Best fitness: 31, Best individual: [5, 1, 18, 0]
# Generation 104, Best fitness: 104, Best individual: [28, 26, 18, 0]
# Generation 105, Best fitness: 54, Best individual: [28, 1, 18, 0]
# Generation 106, Best fitness: 104, Best individual: [28, 26, 18, 0]
# Generation 107, Best fitness: 104, Best individual: [28, 26, 18, 0]
# Generation 108, Best fitness: 104, Best individual: [28, 26, 18, 0]
# Generation 109, Best fitness: 80, Best individual: [28, 26, 10, 0]
# Generation 110, Best fitness: 65, Best individual: [28, 26, 5, 0]
# Generation 111, Best fitness: 65, Best individual: [28, 26, 5, 0]
# Generation 112, Best fitness: 65, Best individual: [28, 26, 5, 0]
# Generation 113, Best fitness: 65, Best individual: [28, 26, 5, 0]
# Generation 114, Best fitness: 34, Best individual: [17, 16, 5, 0]
# Generation 115, Best fitness: 64, Best individual: [17, 16, 15, 0]
# Generation 116, Best fitness: 75, Best individual: [28, 16, 15, 0]
# Generation 117, Best fitness: 75, Best individual: [28, 16, 15, 0]
# Generation 118, Best fitness: 76, Best individual: [9, 26, 15, 0]
# Generation 119, Best fitness: 76, Best individual: [9, 26, 15, 0]
# Generation 120, Best fitness: 61, Best individual: [28, 9, 15, 0]
# Generation 121, Best fitness: 33, Best individual: [18, 0, 15, 0]
# Generation 122, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 123, Best fitness: 74, Best individual: [9, 25, 15, 0]
# Generation 124, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 125, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 126, Best fitness: 74, Best individual: [9, 25, 15, 0]
# Generation 127, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 128, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 129, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 130, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 131, Best fitness: 81, Best individual: [16, 25, 15, 0]
# Generation 132, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 133, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 134, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 135, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 136, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 137, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 138, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 139, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 140, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 141, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 142, Best fitness: 57, Best individual: [18, 12, 15, 0]
# Generation 143, Best fitness: 83, Best individual: [18, 25, 15, 0]
# Generation 144, Best fitness: 95, Best individual: [18, 17, 15, 7]
# Generation 145, Best fitness: 95, Best individual: [18, 17, 15, 7]
# Generation 146, Best fitness: 111, Best individual: [18, 25, 15, 7]
# Generation 147, Best fitness: 111, Best individual: [18, 25, 15, 7]
# Generation 148, Best fitness: 111, Best individual: [18, 25, 15, 7]
# Generation 149, Best fitness: 111, Best individual: [18, 25, 15, 7]
# Generation 150, Best fitness: 107, Best individual: [14, 25, 15, 7]
# Generation 151, Best fitness: 107, Best individual: [14, 25, 15, 7]
# Generation 152, Best fitness: 107, Best individual: [14, 25, 15, 7]
# Generation 153, Best fitness: 111, Best individual: [18, 25, 15, 7]
# Generation 154, Best fitness: 107, Best individual: [14, 25, 15, 7]
# Generation 155, Best fitness: 89, Best individual: [14, 10, 19, 7]
# Generation 156, Best fitness: 89, Best individual: [14, 10, 19, 7]
# Generation 157, Best fitness: 72, Best individual: [9, 10, 15, 7]
# Generation 158, Best fitness: 72, Best individual: [9, 10, 15, 7]
# Generation 159, Best fitness: 72, Best individual: [9, 10, 15, 7]
# Generation 160, Best fitness: 72, Best individual: [9, 10, 15, 7]
# Generation 161, Best fitness: 74, Best individual: [14, 10, 14, 7]
# Generation 162, Best fitness: 59, Best individual: [14, 10, 9, 7]
# Generation 163, Best fitness: 74, Best individual: [14, 10, 14, 7]
# Generation 164, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 165, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 166, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 167, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 168, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 169, Best fitness: 10, Best individual: [14, 10, 2, 0]
# Generation 170, Best fitness: 10, Best individual: [14, 10, 2, 0]
# Generation 171, Best fitness: 32, Best individual: [14, 7, 2, 7]
# Generation 172, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 173, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 174, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 175, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 176, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 177, Best fitness: 10, Best individual: [14, 10, 2, 0]
# Generation 178, Best fitness: 38, Best individual: [14, 10, 2, 7]
# Generation 179, Best fitness: 12, Best individual: [2, 3, 2, 7]
# Generation 180, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 181, Best fitness: 20, Best individual: [24, 10, 2, 0]
# Generation 182, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 183, Best fitness: 2, Best individual: [16, 3, 2, 0]
# Generation 184, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 185, Best fitness: 2, Best individual: [16, 3, 2, 0]
# Generation 186, Best fitness: 2, Best individual: [16, 3, 2, 0]
# Generation 187, Best fitness: 2, Best individual: [16, 3, 2, 0]
# Generation 188, Best fitness: 8, Best individual: [2, 7, 2, 0]
# Generation 189, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 190, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 191, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 192, Best fitness: 8, Best individual: [2, 3, 2, 2]
# Generation 193, Best fitness: 16, Best individual: [2, 3, 2, 0]
# Generation 194, Best fitness: 13, Best individual: [5, 3, 2, 0]
# Generation 195, Best fitness: 34, Best individual: [2, 28, 2, 0]
# Generation 196, Best fitness: 34, Best individual: [2, 28, 2, 0]
# Generation 197, Best fitness: 34, Best individual: [2, 28, 2, 0]
# Generation 198, Best fitness: 11, Best individual: [21, 7, 2, 0]
# Generation 199, Best fitness: 11, Best individual: [21, 7, 2, 0]
# No exact solution found.
# Best solution after 200 generations: [21, 7, 2, 0]
# With Best fitness: 11
# [21, 7, 2, 0]
